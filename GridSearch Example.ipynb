# %%
import io
from scipy.io.arff import loadarff
import matplotlib.pyplot as plt
from sklearn.datasets import get_data_home
from sklearn.externals.joblib import Memory
from sklearn.neural_network import MLPClassifier
try:
    from urllib.request import urlopen
except ImportError:
    # Python 2
    from urllib2 import urlopen
    
memory = Memory(get_data_home())


@memory.cache()
def fetch_mnist():
    content = urlopen(
        'https://www.openml.org/data/download/52667/mnist_784.arff').read()
    data, meta = loadarff(io.StringIO(content.decode('utf8')))
    data = data.view([('pixels', '<f8', 784), ('class', '|S1')])
    return data['pixels'], data['class']

X, y = fetch_mnist()

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC
import numpy as np
print(__doc__)

# Loading the Digits dataset
digits = datasets.load_digits()

# To apply an classifier on this data, we need to flatten the image, to
# turn the data in a (samples, feature) matrix:
n_samples = len(digits.images)
X = digits.images.reshape((n_samples, -1))
y = digits.target

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=45)

# Set the parameters by cross-validation
tuned_parameters = [{'kernel': ['rbf'], 'gamma': [1e-3, 1e-4],
                     'C': [1, 10, 100, 1000]},
                    {'kernel': ['linear'], 'C': [1, 10, 100, 1000]}]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    print()

    clf = GridSearchCV(SVC(), tuned_parameters, cv=5,
                       scoring='%s_macro' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")
    print()
    print(clf.best_params_)
    print()
    print("Grid scores on development set:")
    print()
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r"
              % (mean, std * 2, params))
    print()

    print("Detailed classification report:")
    print()
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print()
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    print()
# Out:
# Automatically created module for IPython interactive environment
# # Tuning hyper-parameters for precision
#
# Best parameters set found on development set:
#
# {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.991 (+/-0.009) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.973 (+/-0.018) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.992 (+/-0.006) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.985 (+/-0.014) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.992 (+/-0.006) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.983 (+/-0.013) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.992 (+/-0.006) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.983 (+/-0.013) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.976 (+/-0.018) for {'C': 1, 'kernel': 'linear'}
# 0.976 (+/-0.018) for {'C': 10, 'kernel': 'linear'}
# 0.976 (+/-0.018) for {'C': 100, 'kernel': 'linear'}
# 0.976 (+/-0.018) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        51
#           1       0.98      1.00      0.99        46
#           2       1.00      1.00      1.00        51
#           3       1.00      1.00      1.00        63
#           4       1.00      1.00      1.00        59
#           5       1.00      0.93      0.97        46
#           6       1.00      1.00      1.00        55
#           7       0.98      0.98      0.98        58
#           8       0.98      0.98      0.98        52
#           9       0.93      0.97      0.95        59
#
# avg / total       0.99      0.99      0.99       540
#
#
# # Tuning hyper-parameters for recall
#
# Best parameters set found on development set:
#
# {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.990 (+/-0.010) for {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.971 (+/-0.020) for {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.991 (+/-0.006) for {'C': 10, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.984 (+/-0.016) for {'C': 10, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.991 (+/-0.006) for {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.982 (+/-0.014) for {'C': 100, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.991 (+/-0.006) for {'C': 1000, 'gamma': 0.001, 'kernel': 'rbf'}
# 0.982 (+/-0.014) for {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# 0.975 (+/-0.019) for {'C': 1, 'kernel': 'linear'}
# 0.975 (+/-0.019) for {'C': 10, 'kernel': 'linear'}
# 0.975 (+/-0.019) for {'C': 100, 'kernel': 'linear'}
# 0.975 (+/-0.019) for {'C': 1000, 'kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00        51
#           1       0.98      1.00      0.99        46
#           2       1.00      1.00      1.00        51
#           3       1.00      1.00      1.00        63
#           4       1.00      1.00      1.00        59
#           5       1.00      0.93      0.97        46
#           6       1.00      1.00      1.00        55
#           7       0.98      0.98      0.98        58
#           8       0.98      0.98      0.98        52
#           9       0.93      0.97      0.95        59
#
# avg / total       0.99      0.99      0.99       540

# %%
parameters={
'learning_rate': ["constant", "invscaling", "adaptive"],
'hidden_layer_sizes': [(10), (10,2), (20,13)],
'alpha': [10.0 ** -np.arange(1, 7)],
'activation': ["logistic", "relu", "Tanh"]
}

clf = gridSearchCV(estimator=MLPClassifier,param_grid=parameters,n_jobs=-1,verbose=2,cv=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-e7054f91877b> in <module>()
#       6 }
#       7
# ----> 8 clf = gridSearchCV(estimator=MLPClassifier,param_grid=parameters,n_jobs=-1,verbose=2,cv=10)
#
# NameError: name 'gridSearchCV' is not defined
